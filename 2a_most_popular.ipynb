# %% [markdown]
# # FOOD RECIPE RECOMMENDATION ENGINE

# %% [markdown]
# ## Part 2a: Most Popular Items

# %%
import pandas as pd
import numpy as np
from src.most_popular import *

# %% [markdown]
# ### Load data

# %%
# Load recipes
recipes = pd.read_feather("./data/recipes.feather")
recipes.drop(["level_0", "index"], axis=1, inplace=True)

# Load interactions
interactions = pd.read_feather("./data/interactions.feather")

# %% [markdown]
# ### Make recommendations

# %%
# Recommend 10 most popular recipes
get_most_popular(10, interactions, recipes)
# Out:
#                                                      name     id  minutes  \
# 574                    Whatever Floats Your Boat Brownies  32204       35
# 22167                                   Best Banana Bread   2886       65
# 22387    Best Ever Banana Cake With Cream Cheese Frosting  67256       75
# 62430                          Creamy Cajun Chicken Pasta  39087       25
# 66686     Crock Pot Chicken With Black Beans Cream Cheese  89204      243
# 115302                   Jo Mama's World Famous Spaghetti  22782       80
# 118160   Kittencal's Italian Melt In Your Mouth Meatballs  69173       50
# 118213  Kittencal's Moist Cheddar Garlic Oven Fried Ch...  82102       60
# 213825                         To Die For Crock Pot Roast  27208      545
# 229261             Yes Virginia There Is A Great Meatloaf  54257       80
#
#         contributor_id   submitted  \
# 574              37305  2002-06-25
# 22167             1762  1999-09-26
# 22387            82367  2003-07-24
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# There is no modeling if we recommend based on the most popular items. We simply tell users the most commonly rated recipes. Here, we tell them the top 10. We could recommend the most popular recipes to users when the site/restaurant is brand new and has not had many visitors. We should then encourage users to rate the recipes they have tried, as well as trying out new recipes to obtain more information.
